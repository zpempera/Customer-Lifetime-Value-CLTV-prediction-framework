# %% [markdown]
# # Customer Lifetime Value (CLTV) Prediction — Olist E-Commerce\n\nThis is a small launcher notebook. The full, GitHub-previewable analysis lives in `cltv_analysis.py`.\n\nRun the code cell below after installing dependencies with `pip install -r requirements.txt`.\n

# %%
# Run the complete CLTV analysis from the plain Python script.\nexec(open("cltv_analysis.py", encoding="utf-8").read())\n
